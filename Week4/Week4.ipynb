# %% [markdown]
# <a href="https://colab.research.google.com/github/Travion25/CSC121-Spring2026-Assignments./blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
  print("*" * 30 )
  print("Name:", name, "Age:", age, "Goal:", goal)
  print("*" * 30 )
# 2. Inside the function, use string multiplication (*) for a border line.
# 3. Print the bio details using the parameter names.

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Travion", 19, "become a Software Developer")
# 2. Call print_bio using [Name of Famous Person].
print_bio("Zendaya", 30, "be like Oprah")
# 3. Call print_bio using [Name of Fictional Character].
print_bio("Spongebob Squarepants", 40, "Make Krabby Patties")
# Out:
# ******************************
# Name: Travion Age: 19 Goal: become a Software Developer
# ******************************
# ******************************
# Name: Zendaya Age: 30 Goal: be like Oprah
# ******************************
# ******************************
# Name: Spongebob Squarepants Age: 40 Goal: Make Krabby Patties
# ******************************
